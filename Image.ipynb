# %% [markdown]
# <a href="https://colab.research.google.com/github/farhadrahimiinfo/Deep-Learning/blob/main/Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#introduction image
import matplotlib.pyplot as plt
import numpy as np
data=plt.imread('./1.png')
plt.imshow(data)
plt.show()
data.shape


data[100,100]

data=np.array(plt.imread('./1.png'))

data

data.shape

plt.imshow(data)
plt.show()

data=np.array(plt.imread('./1.png'))
plt.imshow(data)
plt.show()
data[50:125,50:125,:]=0
plt.imshow(data)
plt.show()

data=np.array(plt.imread('./1.png'))
data[:,:,0]=0
data[:,:,2]=0
plt.imshow(data)
plt.show()

data=np.array(plt.imread('./1.png'))
plt.imshow(data,cmap='gray')
plt.show()

data=np.array(plt.imread('./1.png'))
data_gray=data[:,:,0]//3 + data[:,:,1]//3 + data[:,:,0]//3
plt.imshow(data_gray,cmap='gray')
plt.show()
